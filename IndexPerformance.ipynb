# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
import pandas as pd
import plotly.express as px

# %%
def catch_data(code, start_date, end_date):
    # get data on this ticker
    tickerData = yf.Ticker(code)

    # get the historical prices for this ticker
    tickerDf = tickerData.history(period='1d', start=start_date, end=end_date)
   
    return tickerDf

# %% [markdown]
# Importanto dados

# %%
startdate = '1998-01-01'
#df = yf.download('^BVSP',start = startdate)[['Adj Close']]
df = catch_data('^BVSP','2005-01-01', "2022-10-30")['Close']
df= pd.DataFrame(df)
index = df.copy()
index['ano'] =index.index.year
index['dia_do_ano'] = df.index.dayofyear

# %%
index
# Out:
#                               Close   ano  dia_do_ano
# Date
# 2005-01-03 00:00:00-02:00   25722.0  2005           3
# 2005-01-04 00:00:00-02:00   24848.0  2005           4
# 2005-01-05 00:00:00-02:00   24692.0  2005           5
# 2005-01-06 00:00:00-02:00   24367.0  2005           6
# 2005-01-07 00:00:00-02:00   24747.0  2005           7
# ...                             ...   ...         ...
# 2022-10-24 00:00:00-03:00  116013.0  2022         297
# 2022-10-25 00:00:00-03:00  114626.0  2022         298
# 2022-10-26 00:00:00-03:00  112764.0  2022         299
# 2022-10-27 00:00:00-03:00  114641.0  2022         300
# 2022-10-28 00:00:00-03:00  114539.0  2022         301
#
# [4409 rows x 3 columns]

# %%
tabela = index.pivot(index='dia_do_ano',columns='ano',values = 'Close')
#tabela

# %%
tab = tabela.fillna(method = 'bfill')
tab = (tab/tab.iloc[0])-1 #para gerar a variação percentual em relação ao primeiro dia do ano.

tab
# Out:
# ano             2005      2006      2007      2008      2009      2010  \
# dia_do_ano
# 2           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3           0.000000  0.030859 -0.020669  0.001226  0.031682  0.000000
# 4          -0.033979  0.044618 -0.030033 -0.028305  0.031682  0.000000
# 5          -0.040044  0.042648 -0.069145 -0.032524  0.031682  0.002784
# 6          -0.052679  0.058734 -0.056255 -0.032524  0.051387  0.009765
# ...              ...       ...       ...       ...       ...       ...
# 361         0.297372  0.328857  0.405240 -0.413134  0.687258 -0.032008
# 362         0.288314  0.327305  0.407708 -0.410014  0.687258 -0.028610
# 363         0.300676       NaN       NaN -0.410014  0.697048 -0.015604
# 364              NaN       NaN       NaN -0.410014  0.704304 -0.010565
# 365              NaN       NaN       NaN -0.402213       NaN       NaN
#
# ano             2011      2012      2013      2014      2015      2016  \
# dia_do_ano
# ...

# %% [markdown]
# construindo o gráfico

# %%
#anos= [1998,2002,2006,2010,2014,2018]
anos = [2006,2010,2014,2018]
#Construindo o plot

fig = px.line(
    tab[anos],
    height=600,
    width=800,
    template = 'plotly_dark',
    title = 'Performance iBovespa em anos eleitorais',
    labels={'value':'retorno'}
)

fig.update_traces(
    line=dict(width = 0.6)
)

fig.add_scatter(
    x=tab.index,
    y=tab[2022],
    name='2022',
    line=dict(width = 2)
)

fig.add_vline(x=pd.to_datetime('2022-10-01').dayofyear)
fig.add_vline(x=pd.to_datetime('2022-10-31').dayofyear)
fig.layout.yaxis.tickformat='.0%'

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
